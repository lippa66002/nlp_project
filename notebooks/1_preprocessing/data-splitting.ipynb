# %% [markdown]
# # Introduction
#
# This notebook is dedicated to preparing and organizing the RAG-12000 dataset for downstream tasks such as training, hyperparameter tuning, and evaluation.
#
# We begin by loading and cleaning the dataset, removing null entries and duplicates, and filtering meta-questions. Then we split the dataset into three main parts:
#
# - **Fine-tuning Set** (70%)
# - **Hyperparameter Tuning Set** (15%)
# - **Test Set** (15%)

# %% [markdown]
# #### 1. Dataset Loading and cheking for missing entries/duplicates

# %%
# !git clone https://huggingface.co/datasets/neural-bridge/rag-dataset-12000
# Out:
# Cloning into 'rag-dataset-12000'...
# remote: Enumerating objects: 50, done.
# remote: Total 50 (delta 0), reused 0 (delta 0), pack-reused 50 (from 1)
# Unpacking objects: 100% (50/50), 15.55 KiB | 884.00 KiB/s, done.

# %%
import pandas as pd

test_data=pd.read_parquet("/kaggle/working/rag-dataset-12000/data/test-00000-of-00001-af2a9f454ad1b8a3.parquet")
train_data=pd.read_parquet("/kaggle/working/rag-dataset-12000/data/train-00000-of-00001-9df3a936e1f63191.parquet")
all_data=pd.concat([train_data,test_data])

# %%
#none?
print(f" Context has {all_data['context'].isna().sum()}  none values\n Question has {all_data['question'].isna().sum()} none values\n Answer has {all_data['answer'].isna().sum()} none values")
# Out:
#  Context has 0  none values
#  Question has 3 none values
#  Answer has 3 none values

# %%
cleaned_data=all_data.dropna()

# %%
#duplicates
print(f" Context has {len(cleaned_data['context'].values)-len(cleaned_data['context'].unique())}  duplicates \n Question has {len(cleaned_data['question'].values)-len(cleaned_data['question'].unique())} duplicates\n Answer has {len(cleaned_data['answer'].values)-len(cleaned_data['answer'].unique())} duplicates")
# Out:
#  Context has 0  duplicates
#  Question has 14 duplicates
#  Answer has 0 duplicates

# %%
question_count=cleaned_data.groupby("question").size()
question_count[question_count>1]
# Out:
# question
# What are some of the features that set the Nectar mattress apart from other foam mattresses?    2
# What are some of the job roles mentioned in the context?                                        2
# What are the ingredients needed for the recipe mentioned in the context?                        2
# What is the context about?                                                                      6
# What is the context discussing about?                                                           2
# What is the date mentioned in the context?                                                      2
# What is the main topic discussed in the context?                                                4
# What is the price range of the items listed in the context?                                     2
# dtype: int64

# %%
#search for potential questions related to context
context_queries=cleaned_data[cleaned_data["question"].str.contains('context', case=False)]["question"]
context_queries.shape
context_queries.head(100).values
# Out:
# array(['What is the lunch that Kim and Tony plan to have on Monday according to the context?',
#        'What are the five love and relationship podcasts mentioned in the context?',
#        "What does the word 'quantum' mean as per the context?",
#        "What are the 5 ways to make your Mum's day special according to the context?",
#        'What is a "foster failure" in the context of animal rescue?',
#        'What are the four phenomenological constants described by Schön that could form a matrix for reflective practice within interdisciplinary research contexts?',
#        'Who is the most followed person on Instagram according to the context?',
#        'What is the main concern of the individual in the context about their job title?',
#        'What is the two-step secret to making money on Ebay according to the context?',
#        'What are some of the functions of barstools counter stools on sale ivory swivel mentioned in the context?',
#        'What does the word "Shamo" refer to in the context of bird breeds?',
#        'What is the main topic discussed in the context?',
#        'What is the name of the IBM Thinkpad mentioned in the context?',
#        'What are some examples of hybrid spaces mentioned in the context?',
#        'What is the main theme of the first vignette in the context?',
#        'Who won the Nobel Prize in Literature that the author discusses in the context?',
#        'What is the main focus of the collection mentioned in the context?',
#        'What are the two kinds of action mentioned in the context?',
#        'What are some benefits of walking mentioned in the context?',
#        'What are the weights of William and Esther as mentioned in the context?',
#        'What are the specialties of the professional in Mortgage Lending mentioned in the context?',
#        'What are the "Four Marketing Actions" symbolized by the four leaf clover in the context of inbound marketing?',
#        'What is the potential future use of a "wellness report" as described in the context?',
#        'What are some ideas for wedding invitations mentioned in the context?',
#        'Where can one find free customizable monograms according to the context?',
#        'What are the ingredients required for the lamb korma recipe mentioned in the context?',
#        'What is the purpose of the JavaScript/DOM script mentioned in the context?',
#        'What are some of the potential negative impacts of hunting crows according to the context?',
#        'What is Calvados and how is it used in the context of the Sidecar cocktail?',
#        'What is the benefit of learning multiplication tables according to the context?',
#        'What is the main objective of the seminar mentioned in the context?',
#        'What are the five areas of management discussed in the context?',
#        "What is the theme of International Women's Day as mentioned in the context?",
#        'What are some of the desired features for the game Sea of Thieves according to the context?',
#        'What are some of the business ideas mentioned in the context?',
#        'What are the three young guards discussed in the context?',
#        'What are the steps to prepare the dish mentioned in the context?',
#        'What are the live dates and locations mentioned in the context?',
#        'What is the new era of China-Latin America relations focusing on, according to the context?',
#        'What are some everyday tasks that can be used as therapy equipment according to the context?',
#        "What is the general impression of 24Bulls' educational material according to the context?",
#        'What are some of the criticisms of traditional fairy tales according to the context?',
#        'What are the three assets that could outpace bitcoin in 2021 according to the context?',
#        'What is a crucial aspect to consider for effective communication according to the context?',
#        'What are some of the unique features of the team pages mentioned in the context?',
#        'What is the purpose of the DIY feet in the context?',
#        'What is the main product discussed in the context of fair trade?',
#        "What is the concept of 'criminal-consumer' as proposed in the context?",
#        'What are the key factors to effectively complete homework according to the context?',
#        'What does the context suggest is more important than the content in differentiating between two projects?',
#        'What is the key to making side streets safer according to the context?',
#        'Who are the two Judys mentioned in the context?',
#        'What are some of the findings related to California and Central in the context?',
#        "What is the significance of a patient's medical history according to the context?",
#        'What are the duties related to in the context?',
#        'What is the main character of the context doing?',
#        'What were some of the unique fashion choices made by the children in the context?',
#        'What is the standard meeting time for psychotherapy according to the context?',
#        "What does the acronym MPJ stand for in the context of the men's Christian group?",
#        'What is the argument against physicalism as mentioned in the context?',
#        'What is the birthplace of Judaism and Christianity according to the context?',
#        'What are the dimensions of the flat flexures mentioned in the context?',
#        'What activities are included in the summer program mentioned in the context?',
#        'What is the "fine-grained urbanism" concept proposed by urbanist Andrew Price in the context of Long Beach\'s development?',
#        'What are the four stages of the innovation process as described in the context?',
#        'Who were the defending champions at the U.S. Open mentioned in the context?',
#        'What is a significant part of improving communication skills according to the context?',
#        'Who styled the impromptu photo shoot mentioned in the context?',
#        'What is the life scripture of the person mentioned in the context?',
#        'What is the software mentioned in the context suitable for?',
#        'Who is considered one of the best actors today according to the context?',
#        'What are the two new films beginning their run at the TIFF Lightbox in Toronto according to the context?',
#        'Who are some of the great impressionists mentioned in the context?',
#        'Who is the creator of the unique chocolate flavors mentioned in the context?',
#        'What is the doctrine of equitable subordination in the context of bankruptcy court?',
#        'What is one way to be a witness to other believers according to the context?',
#        'What are some of the health benefits of exercise mentioned in the context?',
#        'Who is preferred over Rattan in the given context?',
#        'What does the House Bill, HB1581, attempt to do according to the context?',
#        'What are the different types of art exhibitions mentioned in the context?',
#        "What is the role of a cloud broker in the context of the General Services Administration's exploration of cloud services?",
#        'How did personal goal setting impact employee engagement and performance in the given context?',
#        'What is the process of creating custom window treatments according to the context?',
#        'What was the change in gold futures on MCX in the given context?',
#        'Who scored the goal for Real Madrid in the match described in the context?',
#        'Who are the two basketball commentators criticized in the context for their remarks?',
#        'What is the shocking truth about making money online according to the context?',
#        'What are the three books mentioned in the context and who are their authors?',
#        'What is the difference between the legalization of interracial marriage and gay marriage according to the context?',
#        'What are the different types of stair treads mentioned in the context?',
#        'What is the primary purpose behind the existence of the nation-state according to the context?',
#        'What is the proposed solution to the problem of increasing healthcare costs and chronic diseases according to the context?',
#        "What does the phrase 'kill your darlings' mean in the context of writing?",
#        'Who are the potential candidates for the starting quarterback position for the Seattle Seahawks as mentioned in the context?',
#        'What are some of the connections between Trump and Russia as mentioned in the context?',
#        'What are some of the challenges faced by Multiple Sclerosis patients as mentioned in the context?',
#        'What are some of the applications of welded wire mesh as mentioned in the context?',
#        'Who is the character that is described as conservative and abstinent in the context?',
#        'What are some foods that can aid in weight loss according to the context?',
#        'What are some of the things that the author believes death gives us according to the context?'],
#       dtype=object)

# %% [markdown]
# #### Around 8% of the dataset was removed because it contained meta-questions mentioning "context", which are not representative of natural user inputs.

# %%
final_data=cleaned_data[~cleaned_data["question"].str.contains("context",case=False)]

# %%
final_data_no_duplicates=final_data.drop_duplicates("question")
final_data_no_duplicates
# Out:
#                                                 context  \
# 0     Caption: Tasmanian berry grower Nic Hansen sho...
# 1     RWSN Collaborations\nSouthern Africa Self-supp...
# 2     All Android applications categories\nDescripti...
# 3     How unequal is India? The question is simple, ...
# 4     Gunnar Nelson took his time on the feet agains...
# ...                                                 ...
# 2395  Fuzzy's Ultra Premium Vodka\nThe Myth, The Man...
# 2396  Swedish Grand Prix rider Malin Nilsson got mar...
# 2397  The Cracchiolo Law Library of the James E. Rog...
# 2398  2nd physical eMAG store opens in Mammut\nOnlin...
# 2399  About This Cadillac\n2019 Cadillac XT5\nFWD 4d...
#
#                                                question  \
# 0     What is the Berry Export Summary 2028 and what...
# 1     What are some of the benefits reported from ha...
# 2     What are the unique features of the Coolands f...
# 3     What is the main difference between the Nation...
# 4     How did Gunnar Nelson win the fight against Za...
# ...                                                 ...
# 2395  What are some of the achievements of Fuzzy Zoe...
# 2396        Who did Malin Nilsson marry on 2 June 2018?
# 2397  What is the Fellowship in Law Librarianship of...
# 2398  Where has the second physical eMAG store been ...
# 2399  What are some of the key features of the 2019 ...
#
#                                                  answer
# 0     The Berry Export Summary 2028 is a dedicated e...
# 1     Benefits reported from having access to Self-s...
# 2     The unique features of the Coolands for Twitte...
# 3     The main difference between the NSS and the IH...
# 4     Gunnar Nelson won the fight against Zak Cummin...
# ...                                                 ...
# 2395  Fuzzy Zoeller is known for his golfing success...
# 2396  Malin Nilsson got married to her partner, Germ...
# 2397  The Fellowship in Law Librarianship is a progr...
# 2398  The second physical eMAG store has been opened...
# 2399  The 2019 Cadillac XT5 comes equipped with feat...
#
# [10937 rows x 3 columns]

# %% [markdown]
# #### General data cleaning

# %%
import re
from bs4 import BeautifulSoup

def clean_text(text):
    if not isinstance(text, str):
        return ""
    text = text.lower()
    text = BeautifulSoup(text, "html.parser").get_text()
    text = re.sub(r"\s+", " ", text).strip()
    return text
final_data_no_duplicates["context"]=final_data_no_duplicates["context"].apply(lambda x : clean_text(x))
# Out:
# /tmp/ipykernel_35/2318288353.py:8: XMLParsedAsHTMLWarning: It looks like you're using an HTML parser to parse an XML document.
#
# Assuming this really is an XML document, what you're doing might work, but you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the Python package 'lxml' installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#
# If you want or need to use an HTML parser on this document, you can make this warning go away by filtering it. To do that, run this code before calling the BeautifulSoup constructor:
#
#     from bs4 import XMLParsedAsHTMLWarning
#     import warnings
#
#     warnings.filterwarnings("ignore", category=XMLParsedAsHTMLWarning)
#
#   text = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_35/2318288353.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_data_no_duplicates["context"]=final_data_no_duplicates["context"].apply(lambda x : clean_text(x))

# %% [markdown]
# #### Data splitting & save

# %%
from sklearn.model_selection import train_test_split
finetuning_data, tmp_data = train_test_split(final_data_no_duplicates, test_size=0.3, random_state=42)
hyperparameter_tuning_data, test_data=train_test_split(tmp_data, test_size=0.5, random_state=42)

finetuning_data.to_parquet("/kaggle/working/finetuning_data.parquet")
hyperparameter_tuning_data.to_parquet("/kaggle/working/hyperparameter_tuning_data.parquet")
test_data.to_parquet("/kaggle/working/test_data.parquet")
